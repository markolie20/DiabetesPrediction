# %%
import pandas as pd
dtypes = train.dtypes
basis_stats = train.describe().T
basis_stats['dtype'] = dtypes
type_stats= basis_stats.reset_index().rename(columns={'index': 'Column Name'})
type_stats
# Out:
#                 Column Name  count        mean         std     min      25%  \
# 0                      p_id  614.0  385.542345  222.135103   0.000  194.250
# 1               Pregnancies  614.0    3.809446    3.375544   0.000    1.000
# 2                   Glucose  614.0  120.465798   31.959619   0.000   99.000
# 3             BloodPressure  614.0   68.903909   19.933385   0.000   62.000
# 4             SkinThickness  614.0   20.456026   16.063105   0.000    0.000
# 5                   Insulin  614.0   81.250814  116.947384   0.000    0.000
# 6                       BMI  614.0   31.929642    8.136791   0.000   27.400
# 7  DiabetesPedigreeFunction  614.0    0.468096    0.329203   0.078    0.238
# 8                       Age  614.0   33.265472   11.851427  21.000   24.000
# 9                   Outcome  614.0    0.342020    0.474773   0.000    0.000
#
#         50%       75%     max    dtype
# 0  380.5000  583.7500  767.00    int64
# 1    3.0000    6.0000   15.00    int64
# ...
